# %%
# %load_ext autoreload
# %autoreload 2

# %% [raw]
# A simple notebook containing run-scripts for globalETAS. specifically, we have one cell for each event of interest; to start with, these are the 2016 m=6.2,7.0 Kyoshi, Japan and m=7.8 Ecuador events.

# %%
import globalETAS_scripts as gesp
import datetime as dtm
% matplotlib inline
import matplotlib.dates as mpd
from imp import reload
import datetime as dtm
import pytz
#
# Out:
# failed while loading urllib and/or urllib. maybe python 3.x?
# /usr/lib/python3/dist-packages/matplotlib/cbook.py:123: MatplotlibDeprecationWarning: The matplotlib.mpl module was deprecated in version 1.3. Use `import matplotlib as mpl` instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fname = 'ecuador%s' % str(dtm.datetime.now(pytz.timezone('UTC'))
fname = fname.replace(' ', '_').replace('.','_')
#print('fname: ', fname)
A_ecuador=gesp.etas_outputs(output_path='/home/myoder/Dropbox/Research/etas/%s' % fname, kml_file='%s.kml' % fname, lats=[.371-7., .371+7.], lons=[-79.94-7., -79.94+7.], mc=2.5, cat_len=3650., etas_range_padding=2.5, etas_range_factor=25.)

# %%
fname = 'kyushu%s' % str(dtm.datetime.now(pytz.timezone('UTC')))
fname = fname.replace(' ', '_').replace('.','_')
#print('fname: ', fname)
A_kyushu=gesp.etas_outputs(output_path='/home/myoder/Dropbox/Research/etas/%s' % fname, kml_file='%s.kml' % fname, lats=[28.5,40.], lons=[126.5,136.], mc=2.5, cat_len=3650., etas_range_padding=2.5, etas_range_factor=25.)

# %%
nepal_epi_lon = 84.698
nepal_epi_lat = 28.175
nepal_dlon = 5.
nepal_dlat = 5.
tzutc = pytz.timezone('UTC')

# %%
fname = 'nepal_%s'% str(dtm.datetime.now(tzutc))
fname = fname.replace(' ', '_').replace('.','_')
#print('fname: ', fname)
A_nepal_2015=gesp.etas_outputs(output_path='/home/myoder/Dropbox/Research/etas/%s' % fname, kml_file='%s.kml' % fname,
                               lons=[nepal_epi_lon-nepal_dlon, nepal_epi_lon+nepal_dlon],
                               lats=[nepal_epi_lat-nepal_dlat, nepal_epi_lat+nepal_dlat],
                               mc=2.5, cat_len=3650., etas_range_padding=2.5, etas_range_factor=25.)

# %%
t_ms=dtm.datetime(2015,4,26, tzinfo=tzutc)
fname = 'nepal_%s'% str(t_ms)
fname = fname.replace(' ', '_').replace('.','_')
# and the historical one...
A_nepal_2016=gesp.etas_outputs(output_path='/home/myoder/Dropbox/Research/etas/%s' % fname, kml_file='%s.kml' % fname, 
                               lons=[nepal_epi_lon-nepal_dlon, nepal_epi_lon+nepal_dlon],
                               lats=[nepal_epi_lat-nepal_dlat, nepal_epi_lat+nepal_dlat], 
                               mc=2.5, cat_len=3650., etas_range_padding=2.5, etas_range_factor=25., t_now=t_ms)

t_ms=dtm.datetime(2015,5,7, tzinfo=tzutc)
fname = 'nepal_%s'% str(t_ms)
fname = fname.replace(' ', '_').replace('.','_')
# and the historical one...
A_nepal_2016b=gesp.etas_outputs(output_path='/home/myoder/Dropbox/Research/etas/%s' % fname, kml_file='%s.kml' % fname, 
                               lons=[nepal_epi_lon-nepal_dlon, nepal_epi_lon+nepal_dlon],
                               lats=[nepal_epi_lat-nepal_dlat, nepal_epi_lat+nepal_dlat], 
                               mc=2.5, cat_len=3650., etas_range_padding=2.5, etas_range_factor=25., t_now=t_ms)
# Out:
# files:  /home/myoder/Dropbox/Research/etas/nepal_2015-04-26_00:00:00+00:00/nepal_2015-04-26_00:00:00+00:00.kml /home/myoder/Dropbox/Research/etas/nepal_2015-04-26_00:00:00+00:00/nepal_2015-04-26_00:00:00+00:00_png.png /home/myoder/Dropbox/Research/etas/nepal_2015-04-26_00:00:00+00:00/nepal_2015-04-26_00:00:00+00:00_xyz.xyz
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-04-28 00:00:00+00:00
# fetch and process catalog.
# etas_prams:  {'lats': [23.175, 33.175], 'dmstar': 1.0, 'incat': None, 'mc': 2.5, 'lons': [79.698, 89.698], 'd_lambda': 1.76, 'q': 1.5, 'b2': 1.5, 'b1': 1.0, 'p': 1.1, 'fit_factor': 1.0, 'd_tau': 2.28, 'D_fract': 1.5, 'date_range': [datetime.datetime(1990, 1, 1, 0, 0, tzinfo=<UTC>), datetime.datetime(2015, 4, 26, 0, 0, tzinfo=<UTC>)], 'do_recarray': True}
# data handle fetched...
#  no file.
# R:  <multiprocessing.pool.ApplyResult object at 0x7fcc295cc518>
# R: data handle fetched...
# data handle fetched...
# data handle fetched...
# data handle fetched...
# data handle fetched...
# data handle fetched...
# data handle fetched...
#  no file. no file. no file. no file. no file. no file. no file.
#  <multiprocessing.pool.ApplyResult object at 0x7fcc295cc5c0>
# R:  <multiprocessing.pool.ApplyResult object at 0x7fcc295cc668>
# R:  <multiprocessing.pool.ApplyResult object at 0x7fcc295cc710>
# R:  <multiprocessing.pool.ApplyResult object at 0x7fcc295cc7b8>
# R:  <multiprocessing.pool.ApplyResult object at 0x7fcc295cc860>
# R:  <multiprocessing.pool.ApplyResult object at 0x7fcc295cc908>
# results fetched.
# catalog fetched and processed.
# ETAS over etas_cat_range/xyz_range:  ([0, 1198], None)
# make_etas():
# etas_mpp worker xyz_range:  [0, 1250]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-04-28 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1198], [0, 1250])
# etas_mpp worker xyz_range:  [1250, 2500]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-04-28 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1198], [1250, 2500])
# etas_mpp worker xyz_range:  [2500, 3750]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-04-28 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1198], [2500, 3750])
# etas_mpp worker xyz_range:  [3750, 5000]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-04-28 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1198], [3750, 5000])
# etas_mpp worker xyz_range:  [5000, 6250]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-04-28 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1198], [5000, 6250])
# etas_mpp worker xyz_range:  [6250, 7500]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-04-28 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1198], [6250, 7500])
# etas_mpp worker xyz_range:  [7500, 8750]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-04-28 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1198], [7500, 8750])
# etas_mpp worker xyz_range:  [8750, 10000]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-04-28 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:
#  ([0, 1198], [8750, 10000])
# /home/myoder/Documents/Research/Yoder/globalETAS/globalETAS.py:1594: RuntimeWarning: divide by zero encountered in true_divide
#   cov = numpy.dot(numpy.array(list(zip(*cat_prime))),numpy.array(cat_prime))/n_dof
# /home/myoder/Documents/Research/Yoder/globalETAS/globalETAS.py:1594: RuntimeWarning: divide by zero encountered in true_divide
#   cov = numpy.dot(numpy.array(list(zip(*cat_prime))),numpy.array(cat_prime))/n_dof
# /home/myoder/Documents/Research/Yoder/globalETAS/globalETAS.py:1594: RuntimeWarning: divide by zero encountered in true_divide
#   cov = numpy.dot(numpy.array(list(zip(*cat_prime))),numpy.array(cat_prime))/n_dof
# /home/myoder/Documents/Research/Yoder/globalETAS/globalETAS.py:1594: RuntimeWarning: divide by zero encountered in true_divide
#   cov = numpy.dot(numpy.array(list(zip(*cat_prime))),numpy.array(cat_prime))/n_dof
# /home/myoder/Documents/Research/Yoder/globalETAS/globalETAS.py:1594: RuntimeWarning: divide by zero encountered in true_divide
#   cov = numpy.dot(numpy.array(list(zip(*cat_prime))),numpy.array(cat_prime))/n_dof
# /home/myoder/Documents/Research/Yoder/globalETAS/globalETAS.py:1594: RuntimeWarning: divide by zero encountered in true_divide
#   cov = numpy.dot(numpy.array(list(zip(*cat_prime))),numpy.array(cat_prime))/n_dof
# /home/myoder/Documents/Research/Yoder/globalETAS/globalETAS.py:1594: RuntimeWarning: divide by zero encountered in true_divide
#   cov = numpy.dot(numpy.array(list(zip(*cat_prime))),numpy.array(cat_prime))/n_dof
# begin make_etas_rtree()
# begin make_etas_rtree()
# begin make_etas_rtree()
# begin make_etas_rtree()
# now gather sub-arrays...
# ETAS complete.begin make_etas_rtree()
# len(local_lattice_dict):  1250
# begin make_etas_rtree()
# begin make_etas_rtree()
# len(local_lattice_dict):  1250
# len(local_lattice_dict):  1250
# len(local_lattice_dict):  1250
# begin make_etas_rtree()
# len(local_lattice_dict):  1250
# Indices initiated. begin ETAS :: len(local_lattice_dict): len(local_lattice_dict): Indices initiated. begin ETAS :: Indices initiated. begin ETAS :: Indices initiated. begin ETAS :: len(local_lattice_dict): Indices initiated. begin ETAS ::  [0, 1198]
#  1250
#  1250
#  [0, 1198]
#  [0, 1198]
#  [0, 1198]
#  1250
#  [0, 1198]
# etas complete (from mpp_rtree run() loop); now pipe back([0, 1198])Indices initiated. begin ETAS :: Indices initiated. begin ETAS :: etas complete (from mpp_rtree run() loop); now pipe back([0, 1198])etas complete (from mpp_rtree run() loop); now pipe back([0, 1198])etas complete (from mpp_rtree run() loop); now pipe back([0, 1198])Indices initiated. begin ETAS :: etas complete (from mpp_rtree run() loop); now pipe back([0, 1198])
#  [0, 1198]
#  [0, 1198]
#
#
#
#  [0, 1198]
#
# etas complete (from mpp_rtree run() loop); now pipe back([0, 1198])etas complete (from mpp_rtree run() loop); now pipe back([0, 1198])etas complete (from mpp_rtree run() loop); now pipe back([0, 1198])
# kml bottom, top:
#  0 24
# files:
#  /home/myoder/Dropbox/Research/etas/nepal_2015-05-07_00:00:00+00:00/nepal_2015-05-07_00:00:00+00:00.kml /home/myoder/Dropbox/Research/etas/nepal_2015-05-07_00:00:00+00:00/nepal_2015-05-07_00:00:00+00:00_png.png /home/myoder/Dropbox/Research/etas/nepal_2015-05-07_00:00:00+00:00/nepal_2015-05-07_00:00:00+00:00_xyz.xyz
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-05-09 00:00:00+00:00
# fetch and process catalog.
# etas_prams:  {'lats': [23.175, 33.175], 'dmstar': 1.0, 'incat': None, 'mc': 2.5, 'lons': [79.698, 89.698], 'd_lambda': 1.76, 'q': 1.5, 'b2': 1.5, 'b1': 1.0, 'p': 1.1, 'fit_factor': 1.0, 'd_tau': 2.28, 'D_fract': 1.5, 'date_range': [datetime.datetime(1990, 1, 1, 0, 0, tzinfo=<UTC>), datetime.datetime(2015, 5, 7, 0, 0, tzinfo=<UTC>)], 'do_recarray': True}
# data handle fetched...
#  no file.
# R:  <multiprocessing.pool.ApplyResult object at 0x7fcc2371dcc0>
# R: data handle fetched...
# data handle fetched...
# data handle fetched...
# data handle fetched...
# data handle fetched...
# data handle fetched...
# data handle fetched...
#  no file. no file. no file. no file. no file. no file. no file.
#  <multiprocessing.pool.ApplyResult object at 0x7fcc2371dc50>
# R:  <multiprocessing.pool.ApplyResult object at 0x7fcc2371da20>
# R:  <multiprocessing.pool.ApplyResult object at 0x7fcc2371d7b8>
# R:  <multiprocessing.pool.ApplyResult object at 0x7fcc2371d208>
# R:  <multiprocessing.pool.ApplyResult object at 0x7fcc2371d240>
# R:  <multiprocessing.pool.ApplyResult object at 0x7fcc2371d160>
# results fetched.
# catalog fetched and processed.
# ETAS over etas_cat_range/xyz_range:  ([0, 1262], None)
# make_etas():
# etas_mpp worker xyz_range:  [0, 1250]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-05-09 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1262], [0, 1250])
# etas_mpp worker xyz_range:  [1250, 2500]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-05-09 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1262], [1250, 2500])
# etas_mpp worker xyz_range:  [2500, 3750]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-05-09 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1262], [2500, 3750])
# etas_mpp worker xyz_range:  [3750, 5000]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-05-09 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1262], [3750, 5000])
# etas_mpp worker xyz_range:  [5000, 6250]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-05-09 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1262], [5000, 6250])
# etas_mpp worker xyz_range:  [6250, 7500]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-05-09 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1262], [6250, 7500])
# etas_mpp worker xyz_range:  [7500, 8750]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-05-09 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1262], [7500, 8750])
# etas_mpp worker xyz_range:  [8750, 10000]
# begin globalETAS.__init()__
# Overriding t0 for ETAS calculations. using catalog start, t0 = t_now - catlen (3650.000000) = 2005-05-09 00:00:00+00:00
# ETAS over etas_cat_range/xyz_range:  ([0, 1262], [8750, 10000])
# /home/myoder/Documents/Research/Yoder/globalETAS/globalETAS.py:1594: RuntimeWarning: divide by zero encountered in true_divide
#   cov = numpy.dot(numpy.array(list(zip(*cat_prime))),numpy.array(cat_prime))/n_dof
# /home/myoder/Documents/Research/Yoder/globalETAS/globalETAS.py:1594: RuntimeWarning: divide by zero encountered in true_divide
#   cov = numpy.dot(numpy.array(list(zip(*cat_prime))),numpy.array(cat_prime))/n_dof
# /home/myoder/Documents/Research/Yoder/globalETAS/globalETAS.py:1594: RuntimeWarning: divide by zero encountered in true_divide
#   cov = numpy.dot(numpy.array(list(zip(*cat_prime))),numpy.array(cat_prime))/n_dof
# /home/myoder/Documents/Research/Yoder/globalETAS/globalETAS.py:1594: RuntimeWarning: divide by zero encountered in true_divide
#   cov = numpy.dot(numpy.array(list(zip(*cat_prime))),numpy.array(cat_prime))/n_dof
# /home/myoder/Documents/Research/Yoder/globalETAS/globalETAS.py:1594: RuntimeWarning: divide by zero encountered in true_divide
#   cov = numpy.dot(numpy.array(list(zip(*cat_prime))),numpy.array(cat_prime))/n_dof
# /home/myoder/Documents/Research/Yoder/globalETAS/globalETAS.py:1594: RuntimeWarning: divide by zero encountered in true_divide
#   cov = numpy.dot(numpy.array(list(zip(*cat_prime))),numpy.array(cat_prime))/n_dof
# /home/myoder/Documents/Research/Yoder/globalETAS/globalETAS.py:1594: RuntimeWarning: divide by zero encountered in true_divide
#   cov = numpy.dot(numpy.array(list(zip(*cat_prime))),numpy.array(cat_prime))/n_dof
# begin make_etas_rtree()
# begin make_etas_rtree()
# begin make_etas_rtree()
# len(local_lattice_dict):  1250
# begin make_etas_rtree()
# begin make_etas_rtree()
# len(local_lattice_dict):  1250
# now gather sub-arrays...
# ETAS complete.begin make_etas_rtree()
# begin make_etas_rtree()
# len(local_lattice_dict):  1250
# len(local_lattice_dict):  1250
# len(local_lattice_dict):  1250
# begin make_etas_rtree()
# Indices initiated. begin ETAS :: Indices initiated. begin ETAS :: len(local_lattice_dict):  1250
#  [0, 1262]
# len(local_lattice_dict):  1250
#  [0, 1262]
# len(local_lattice_dict):  1250
# Indices initiated. begin ETAS :: Indices initiated. begin ETAS :: Indices initiated. begin ETAS :: Indices initiated. begin ETAS :: etas complete (from mpp_rtree run() loop); now pipe back([0, 1262])Indices initiated. begin ETAS :: etas complete (from mpp_rtree run() loop); now pipe back([0, 1262])Indices initiated. begin ETAS ::  [0, 1262]
#  [0, 1262]
#  [0, 1262]
#  [0, 1262]
#
#  [0, 1262]
#
#  [0, 1262]
# etas complete (from mpp_rtree run() loop); now pipe back([0, 1262])etas complete (from mpp_rtree run() loop); now pipe back([0, 1262])etas complete (from mpp_rtree run() loop); now pipe back([0, 1262])etas complete (from mpp_rtree run() loop); now pipe back([0, 1262])etas complete (from mpp_rtree run() loop); now pipe back([0, 1262])etas complete (from mpp_rtree run() loop); now pipe back([0, 1262])
# kml bottom, top:
#  0 23
